# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Santhosh Suryadevara__

# %% [markdown]
# AI/ML Specialist

# %% [markdown]
# _I am interested in data science to improve my career opportunities_

# %% [markdown]
# ### Addition of two numbers

# %%
2+2
# Out:
# 4

# %% [markdown]
# ***

# %% [markdown]
# - First
# - Second
# - Third
#     - Sub Third

# %% [markdown]
# 1. First
# 2. Second
# 3. Third

# %% [markdown]
# <table>
#     <th><tr><td>Column1</td><td>Column2</td></tr></th>
#     <tr><td>Column1</td><td>Column2</td></tr>
#     <tr><td>Column1</td><td>Column2</td></tr>
# </table>
